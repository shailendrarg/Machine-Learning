# %%
import pandas as pd
df=pd.read_csv("BL-Flickr-Images-Book.csv",encoding="ISO-8859-1") # encoding error s removed

# %%
df.head()
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of All for Gr...  A., A. A.
# ...

# %%
#lets see our columns
df.columns
# Out:
# Index(['Identifier', 'Edition Statement', 'Place of Publication',
#        'Date of Publication', 'Publisher', 'Title', 'Author', 'Contributors',
#        'Corporate Author', 'Corporate Contributors', 'Former owner',
#        'Engraver', 'Issuance type', 'Flickr URL', 'Shelfmarks'],
#       dtype='object')

# %%
df.isnull().sum() # Missing data found
# Out:
# Identifier                   0
# Edition Statement         7514
# Place of Publication         0
# Date of Publication        181
# Publisher                 4195
# Title                        0
# Author                    1778
# Contributors                 0
# Corporate Author          8287
# Corporate Contributors    8287
# Former owner              8286
# Engraver                  8287
# Issuance type                0
# Flickr URL                   0
# Shelfmarks                   0
# dtype: int64

# %%
df.count() # tells us total rows are 8287, since some columns are all NaN values, lets drop them.
# Out:
# Identifier                8287
# Edition Statement          773
# Place of Publication      8287
# Date of Publication       8106
# Publisher                 4092
# Title                     8287
# Author                    6509
# Contributors              8287
# Corporate Author             0
# Corporate Contributors       0
# Former owner                 1
# Engraver                     0
# Issuance type             8287
# Flickr URL                8287
# Shelfmarks                8287
# dtype: int64

# %%
drop_columns= ["Edition Statement",'Corporate Author', 'Corporate Contributors', 'Former owner','Engraver', ]
df.drop(columns =drop_columns,inplace=True,axis=1)#axis=1 means drop the columns

# %%
df.columns
# Out:
# Index(['Identifier', 'Place of Publication', 'Date of Publication',
#        'Publisher', 'Title', 'Author', 'Contributors', 'Issuance type',
#        'Flickr URL', 'Shelfmarks'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8287 entries, 0 to 8286
# Data columns (total 10 columns):
# Identifier              8287 non-null int64
# Place of Publication    8287 non-null object
# Date of Publication     8106 non-null object
# Publisher               4092 non-null object
# Title                   8287 non-null object
# Author                  6509 non-null object
# Contributors            8287 non-null object
# Issuance type           8287 non-null object
# Flickr URL              8287 non-null object
# Shelfmarks              8287 non-null object
# dtypes: int64(1), object(9)
# memory usage: 647.5+ KB

# %%
df.duplicated().sum() # no duplicate entry in the data
# Out:
# 0

# %%
df.head()
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London         1879 [1878]
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author                                  Contributors Issuance type  \
# ...

# %%
#lets check the publication date column as it has discrepencies like 1879 [1878]
df["Date of Publication"].head(50)
# Out:
# 0            1879 [1878]
# 1                   1868
# 2                   1869
# 3                   1851
# 4                   1857
# 5                   1875
# 6                   1872
# 7                    NaN
# 8                   1676
# 9                   1679
# 10                  1802
# 11                  1859
# 12                  1888
# 13           1839, 38-54
# 14                  1897
# 15                  1865
# 16               1860-63
# 17                  1873
# 18                  1866
# 19                  1899
# 20                  1814
# 21                  1820
# 22                  1800
# 23    1847, 48 [1846-48]
# 24               [1897?]
# 25               [1897?]
# 26                  1893
# 27                  1805
# 28                  1837
# 29                  1896
# 30                  1898
# 31                  1899
# 32                  1892
# 33                  1894
# 34              [1894-96
# 35                   NaN
# 36                  1899
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8287 entries, 0 to 8286
# Data columns (total 10 columns):
# Identifier              8287 non-null int64
# Place of Publication    8287 non-null object
# Date of Publication     8106 non-null object
# Publisher               4092 non-null object
# Title                   8287 non-null object
# Author                  6509 non-null object
# Contributors            8287 non-null object
# Issuance type           8287 non-null object
# Flickr URL              8287 non-null object
# Shelfmarks              8287 non-null object
# dtypes: int64(1), object(9)
# memory usage: 647.5+ KB

# %%
df["Date of Publication"].isnull().sum()     # 181 bad values
# Out:
# 181

# %%
# how to list thosebad values
list1=df["Date of Publication"].tolist()

# %%
list1 # converting the listinto string
# Out:
# ['1879 [1878]',
#  '1868',
#  '1869',
#  '1851',
#  '1857',
#  '1875',
#  '1872',
#  nan,
#  '1676',
#  '1679',
#  '1802',
#  '1859',
#  '1888',
#  '1839, 38-54',
#  '1897',
#  '1865',
#  '1860-63',
#  '1873',
#  '1866',
#  '1899',
#  '1814',
#  '1820',
#  '1800',
#  '1847, 48 [1846-48]',
#  '[1897?]',
#  '[1897?]',
#  '1893',
#  '1805',
#  '1837',
#  '1896',
#  '1898',
#  '1899',
#  '1892',
#  '1894',
#  '[1894-96',
#  nan,
#  '1899',
#  '[1885]',
#  '[1860?]',
#  '1846',
#  '1893',
#  '1894',
#  '1817',
#  '1816',
#  '1817',
#  '1897',
#  '[1833]',
#  '1804',
#  '1859',
#  '1777',
#  '1799',
#  '1827',
#  '1866',
#  '1853',
#  '1874',
#  '1790',
#  '[1817.]',
#  '1883',
#  '1795',
#  '1865',
#  '1877',
#  '1853',
#  '1886, [1885]',
#  '[1834]',
#  '1852-63',
#  '1857',
#  '1866, 76',
#  '1869',
#  '1853',
#  '1875',
#  '1827',
#  '1828',
#  '1876',
#  '1758',
#  '1846',
#  '1880',
#  '1823',
#  '1887',
#  '1825',
#  '1850',
#  '1810',
#  '1889',
#  '1872',
#  '1892',
# ...

# %%
unwanted_characters = ['[', ',', '-']

def clean_dates(dop):
    dop = str(dop)
    if dop.startswith('[') or dop == 'nan':
        return 'NaN'
    for character in unwanted_characters:
        if character in dop:
            character_index = dop.find(character)
            dop = dop[:character_index]
    return dop
dop=df['Date of Publication']
clean_dates(dop)

df['Date of Publication'] = df['Date of Publication'].apply(clean_dates)
# Out:
# character index 879
# dop 0       1879
# 1        1868
# 2        1869
# 3        1851
# 4        1857
# 5        1875
# 6        1872
# 7         NaN
# 8        1676
# 9        1679
# 10       1802
# 11       1859
# 12       1888
# 13       1839
# 14       1897
# 15       1865
# 16       1860
# 17       1873
# 18       1866
# 19       1899
# 20       1814
# 21       1820
# 22       1800
# 23       1847
# 24        NaN
# 25        NaN
# 26       1893
# 27       1805
# 28       1837
# 29       1896
#         ...
# 8257      NaN
# 8258     1896
# 8259      NaN
# 8260      NaN
# 8261     1750
# 8262     1879
# 8263      NaN
# 8264     1889
# 8265      NaN
# 8266     1876
# 8267      NaN
# 8268      NaN
# 8269     1708
# 8270      NaN
# 8271     1777
# 8272      NaN
# 8273     1866
# 8274     1862
# 8275     1894
# 8276     1868
# 8277     1882
# 8278     1883
# 8279     1898
# 8280     1811
# 8281     1867
# 8282     1838
# 8283     1831
# 8284      NaN
# 8285     1834
# 8286     1834
# ...

# %%
df['Date of Publication']

# %%
#letsDrop the NaN values in Date of Publication
df2=df[df['Date of Publication']!="NaN"]
df2
# Out:
#       Identifier      Place of Publication Date of Publication  \
# 0            206                    London               1879
# 1            216  London; Virtue & Yorston                1868
# 2            218                    London                1869
# 3            472                    London                1851
# 4            480                    London                1857
# 5            481                    London                1875
# 6            519                    London                1872
# 8            874                   London]                1676
# 9           1143                    London                1679
# 10          1280                  Coventry                1802
# 11          1808               Christiania                1859
# 12          1905                   Firenze                1888
# 13          1929                 Amsterdam                1839
# 14          2836                    Savona                1897
# ...

# %%
#lets clean the place of Publication
df2["Place of Publication"]
# Out:
# 0                         London
# 1       London; Virtue & Yorston
# 2                         London
# 3                         London
# 4                         London
# 5                         London
# 6                         London
# 8                        London]
# 9                         London
# 10                      Coventry
# 11                   Christiania
# 12                       Firenze
# 13                     Amsterdam
# 14                        Savona
# 15                        London
# 16                         Paris
# 17                         Paris
# 18                   Puerto-Rico
# 19                      New York
# 20                          Hull
# 21                        London
# 22                        Oxonii
# 23                        London
# 26                        Milano
# 27                        London
# 28                      Aberdeen
# 29                          Wien
# 30                      Abingdon
# ...

# %%
unwanted_values=[";","]"]
def clean_publication(dop)
    dop=str(dop)
    if dop.endswith("]")or dop="NaN":
        return NaN
    for characters in unwanted_values:
        if characters in dop:
        dop_index=dop.find(characters)
        print("index",dop_index)
        dop=dop[:dop_index]
    return

# %%
df2.Author
